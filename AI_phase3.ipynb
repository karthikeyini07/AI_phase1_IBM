# %% [markdown]
# #**Market Basket Insights**
#
# **Step 1** : **Data Loading**
#
# We'll start by loading the dataset using pandas.

# %%
# Import the necessary libraries
import pandas as pd

# Load the dataset from the provided CSV file
path= "/content/Assignment-1_Data.csv"
data = pd.read_csv(path, delimiter=";")


# Display the first few rows of the dataset to get an overview
data.head()
# Out:
# <ipython-input-10-40c32d2809ce>:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(path, delimiter=";")
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %% [markdown]
# **Explanation:**
#
# *  We import the pandas library to work with data.
# *  We use the read_csv function to read the data from the "Assignment-1_Data.csv"
# file and store it in the data DataFrame.
# *  We display the first few rows of the dataset using the head() function to understand the data structure.
#
# **Step 2 : Data Exploration**
#
# In this step, we'll perform some basic data exploration to better understand the dataset.

# %%
# Check the dimensions of the dataset (number of rows and columns)
data_shape = data.shape
print("Dataset Shape: ", data_shape)

# Summary statistics for numerical columns
summary_stats = data.describe()
print("Summary Statistics: \n", summary_stats)

# Check for missing values in the dataset
missing_values = data.isnull().sum()
print("Missing Values: \n", missing_values)
# Out:
# Dataset Shape:  (522064, 7)
# Summary Statistics:
#              Quantity     CustomerID
# count  522064.000000  388023.000000
# mean       10.090435   15316.931710
# std       161.110525    1721.846964
# min     -9600.000000   12346.000000
# 25%         1.000000   13950.000000
# 50%         3.000000   15265.000000
# 75%        10.000000   16837.000000
# max     80995.000000   18287.000000
# Missing Values:
#  BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %% [markdown]
# **Explanation:**
#
# *  We use the shape attribute to get the dimensions of the dataset (number of rows and columns).
# *  describe() provides summary statistics (mean, min, max, etc.) for numerical columns in the dataset.
# *  isnull().sum() is used to count missing values in each column.
#
# **Step 3 : Data Preprocessing**
#
# Now, let's perform some data preprocessing steps.

# %%
# Dropping rows with missing values (NaN) if needed
data_cleaned = data.dropna()

# Checking the new dimensions after removing missing values
data_cleaned_shape = data_cleaned.shape

# Checking for duplicate rows
duplicates = data_cleaned.duplicated().sum()

# Check unique values in each column
unique_values = data_cleaned.nunique()

# Checking data types of each column
data_types = data_cleaned.dtypes

# Data transformation if needed
# For example, converting date columns to datetime objects

data_cleaned.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %% [markdown]
# **Explanation:**
#
# *  We can choose to either drop rows with missing values (NaN) or fill them based on the problem's requirements. In this example, we drop them.
# *  We calculate the dimensions of the cleaned dataset after removing missing values.
# *  We check for duplicate rows using the duplicated() function.
# *  We calculate the number of unique values in each column using nunique().
# *  We check the data types of each column using dtypes.
#
# **Step 4: Basic Analysis**
#
# Now, we'll perform some basic analysis to understand the data distribution.

# %%
# Check the data type of the 'BillNo' column
print(data_cleaned['BillNo'].dtype)

# If it's not numeric, attempt to convert it to integers (assuming it contains integer-like values)
data_cleaned['BillNo'] = data_cleaned['BillNo'].astype(str).str.extract('(\d+)').astype(float)

# Check the data type again
print(data_cleaned['BillNo'].dtype)

# Now, create the histogram
plt.hist(data_cleaned['BillNo'], bins=20)
plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.title('Histogram of BillNo')
plt.show()
# Out:
# object
# <ipython-input-20-06feea98eb18>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['BillNo'] = data_cleaned['BillNo'].astype(str).str.extract('(\d+)').astype(float)
# float64

# %% [markdown]
# **Explanation:**
#
# *  We can count the occurrences of each unique value in a specific column using value_counts().
# Grouping and aggregation are often useful for summarizing data.
# *  We demonstrate a simple histogram plot using matplotlib.
# These steps cover data loading, exploration, preprocessing, and basic analysis. You can tailor these steps to your specific dataset and project requirements.

# %% [markdown]
# NANDHA COLLEGE OF TECHNOLOGY
